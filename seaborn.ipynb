# %%
# Importing seaborn library
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Loading example dataset
tips = sns.load_dataset('tips')

# %%
# Simple Scatter Plot
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Scatter Plot')
plt.show()

# %%
# Simple Line Plot
sns.lineplot(x='size', y='total_bill', data=tips)
plt.title('Line Plot')
plt.show()

# %%
# Simple Bar Plot
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Bar Plot')
plt.show()

# %%
# Simple Histogram
sns.histplot(tips['total_bill'], bins=30)
plt.title('Histogram')
plt.show()

# %%
# Simple Box Plot
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Box Plot')
plt.show()

# %%
# Simple Violin Plot
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin Plot')
plt.show()

# %%
# Simple KDE Plot
sns.kdeplot(tips['total_bill'])
plt.title('KDE Plot')
plt.show()

# %%
# Pair Plot
sns.pairplot(tips)
plt.title('Pair Plot')
plt.show()

# %%
# Heatmap
corr = tips.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap')
plt.show()
# Out:
# C:\Users\KRUSHNA KOUSHIK\AppData\Local\Temp\ipykernel_20896\4256964606.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = tips.corr()

# %%
# Simple Count Plot
sns.countplot(x='day', data=tips)
plt.title('Count Plot')
plt.show()

# %%
# Simple Strip Plot
sns.stripplot(x='day', y='total_bill', data=tips)
plt.title('Strip Plot')
plt.show()

# %%
# Simple Swarm Plot
sns.swarmplot(x='day', y='total_bill', data=tips)
plt.title('Swarm Plot')
plt.show()

# %%
# Simple Factor Plot
sns.catplot(x='day', y='total_bill', hue='sex', data=tips, kind='bar')
plt.title('Factor Plot')
plt.show()

# %%
# Simple Joint Plot
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')
plt.title('Joint Plot')
plt.show()

# %%
# Simple Regression Plot
sns.regplot(x='total_bill', y='tip', data=tips)
plt.title('Regression Plot')
plt.show()

# %%
# Simple Rug Plot
sns.rugplot(tips['total_bill'])
plt.title('Rug Plot')
plt.show()

# %%
# Simple Point Plot
sns.pointplot(x='day', y='total_bill', data=tips)
plt.title('Point Plot')
plt.show()

# %%
# Simple Cat Plot
sns.catplot(x='day', y='total_bill', data=tips)
plt.title('Cat Plot')
plt.show()
